# %%
import numpy as np

# %% [markdown]
# ### Question 1:
# Version of NumPy

# %%
np.__version__
# Out:
# '1.21.5'

# %%
import pandas as pd

# %%
# read data.txt as dataset 

dataset = pd.read_csv('data.txt')

# %%
dataset
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %% [markdown]
# ### Question 2:
# How many records are in the dataset?

# %%
dataset.shape[0]
# Out:
# 11914

# %% [markdown]
# ### Question 3:
# Who are the most frequent car manufacturers (top-3) according to the dataset?

# %%
df1 = dataset.groupby('Make').count()

# %%
df1.Model.sort_values(ascending = False)[:3]
# Out:
# Make
# Chevrolet     1123
# Ford           881
# Volkswagen     809
# Name: Model, dtype: int64

# %% [markdown]
# ### Question 4:
# What's the number of unique Audi car models in the dataset?

# %%
dataset[dataset['Make'] == "Audi"].Model.nunique()
# Out:
# 34

# %% [markdown]
# ### Question 5:
# How many columns in the dataset have missing values?

# %%
dataset.isna().sum().sort_values()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Transmission Type       0
# Driven_Wheels           0
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# Engine Fuel Type        3
# Number of Doors         6
# Engine Cylinders       30
# Engine HP              69
# Market Category      3742
# dtype: int64

# %% [markdown]
# ### Question 6:
# 1. Find the median value of "Engine Cylinders" column in the dataset.

# %%
dataset['Engine Cylinders'].median()
# Out:
# 6.0

# %% [markdown]
# ### Question 6:
#
# 2. Next, calculate the most frequent value of the same "Engine Cylinders".

# %%
dataset['Engine Cylinders'].mode()
# Out:
# 0    4.0
# Name: Engine Cylinders, dtype: float64

# %%
df2 = dataset.groupby('Engine Cylinders').count()
df2
# Out:
#                   Make  Model  Year  Engine Fuel Type  Engine HP  \
# Engine Cylinders
# 0.0                 56     56    56                56         13
# 3.0                 30     30    30                30         30
# 4.0               4752   4752  4752              4752       4743
# 5.0                225    225   225               225        225
# 6.0               4489   4489  4489              4486       4473
# 8.0               2031   2031  2031              2031       2031
# 10.0                68     68    68                68         68
# 12.0               230    230   230               230        230
# 16.0                 3      3     3                 3          3
#
#                   Transmission Type  Driven_Wheels  Number of Doors  \
# Engine Cylinders
# 0.0                              56             56               51
# 3.0                              30             30               30
# 4.0                            4752           4752             4752
# ...

# %% [markdown]
# Note that Engine Cylinders corresponding to 4 has the maximum value of 4752. Hence the answer is 4.

# %% [markdown]
# ### Question 6:
#
# 3. Use the fillna method to fill the missing values in "Engine Cylinders" with the most frequent value from the previous step.

# %%
dataset['Engine Cylinders'] = dataset['Engine Cylinders'].fillna(4)

# %%
dataset.groupby('Engine Cylinders').count()
# Out:
#                   Make  Model  Year  Engine Fuel Type  Engine HP  \
# Engine Cylinders
# 0.0                 56     56    56                56         13
# 3.0                 30     30    30                30         30
# 4.0               4782   4782  4782              4782       4772
# 5.0                225    225   225               225        225
# 6.0               4489   4489  4489              4486       4473
# 8.0               2031   2031  2031              2031       2031
# 10.0                68     68    68                68         68
# 12.0               230    230   230               230        230
# 16.0                 3      3     3                 3          3
#
#                   Transmission Type  Driven_Wheels  Number of Doors  \
# Engine Cylinders
# 0.0                              56             56               51
# 3.0                              30             30               30
# 4.0                            4782           4782             4782
# ...

# %% [markdown]
# Note the value corresponding to 4 Engine Cylinders has increased by 30 to 4782.

# %% [markdown]
# ### Question 6:
# 4. Now, calculate the median value of "Engine Cylinders" once again.

# %%
dataset['Engine Cylinders'].median()
# Out:
# 6.0

# %% [markdown]
# Has it changed?
#
# Answer is No.

# %% [markdown]
# ### Question 7:
# 1. Select all the "Lotus" cars from the dataset.

# %%
Lotus = dataset[dataset['Make'] == 'Lotus']
Lotus
# Out:
#        Make      Model  Year                Engine Fuel Type  Engine HP  \
# 3912  Lotus      Elise  2009     premium unleaded (required)      189.0
# 3913  Lotus      Elise  2009     premium unleaded (required)      218.0
# 3914  Lotus      Elise  2009     premium unleaded (required)      189.0
# 3915  Lotus      Elise  2010     premium unleaded (required)      189.0
# 3916  Lotus      Elise  2010     premium unleaded (required)      218.0
# 3917  Lotus      Elise  2011     premium unleaded (required)      189.0
# 3918  Lotus      Elise  2011     premium unleaded (required)      217.0
# 3919  Lotus      Elise  2011     premium unleaded (required)      217.0
# 4216  Lotus     Esprit  2002     premium unleaded (required)      350.0
# 4217  Lotus     Esprit  2003     premium unleaded (required)      350.0
# 4218  Lotus     Esprit  2004     premium unleaded (required)      350.0
# 4257  Lotus  Evora 400  2017     premium unleaded (required)      400.0
# ...

# %% [markdown]
# 2. Select only columns "Engine HP", "Engine Cylinders".

# %%
Lotus1 = Lotus[['Engine HP', 'Engine Cylinders']]
Lotus1
# Out:
#       Engine HP  Engine Cylinders
# 3912      189.0               4.0
# 3913      218.0               4.0
# 3914      189.0               4.0
# 3915      189.0               4.0
# 3916      218.0               4.0
# 3917      189.0               4.0
# 3918      217.0               4.0
# 3919      217.0               4.0
# 4216      350.0               8.0
# 4217      350.0               8.0
# 4218      350.0               8.0
# 4257      400.0               6.0
# 4258      400.0               6.0
# 4259      276.0               6.0
# 4260      276.0               6.0
# 4261      276.0               6.0
# 4262      345.0               6.0
# 4263      345.0               6.0
# 4264      276.0               6.0
# 4265      345.0               6.0
# 4266      276.0               6.0
# 4267      345.0               6.0
# 4268      276.0               6.0
# 4292      257.0               4.0
# 4293      240.0               4.0
# 4294      240.0               4.0
# ...

# %% [markdown]
# 3. Now drop all duplicated rows using drop_duplicates method (you should get a dataframe with 9 rows).

# %%
Lotus1 = Lotus1.drop_duplicates()
Lotus1
# Out:
#       Engine HP  Engine Cylinders
# 3912      189.0               4.0
# 3913      218.0               4.0
# 3918      217.0               4.0
# 4216      350.0               8.0
# 4257      400.0               6.0
# 4259      276.0               6.0
# 4262      345.0               6.0
# 4292      257.0               4.0
# 4293      240.0               4.0

# %% [markdown]
# 4. Get the underlying NumPy array. Let's call it X.

# %%
X = np.array(Lotus1)

# %%
X
# Out:
# array([[189.,   4.],
#        [218.,   4.],
#        [217.,   4.],
#        [350.,   8.],
#        [400.,   6.],
#        [276.,   6.],
#        [345.,   6.],
#        [257.,   4.],
#        [240.,   4.]])

# %% [markdown]
# 5. Compute matrix-matrix multiplication between the transpose of X and X. To get the transpose, use X.T. Let's call the result XTX.

# %%
X.T
# Out:
# array([[189., 218., 217., 350., 400., 276., 345., 257., 240.],
#        [  4.,   4.,   4.,   8.,   6.,   6.,   6.,   4.,   4.]])

# %%
XTX = X.T.dot(X)

# %%
XTX
# Out:
# array([[7.31684e+05, 1.34100e+04],
#        [1.34100e+04, 2.52000e+02]])

# %% [markdown]
# 6. Invert XTX.

# %%
XTX_inv = np.linalg.inv(XTX)

# %%
XTX_inv
# Out:
# array([[ 5.53084235e-05, -2.94319825e-03],
#        [-2.94319825e-03,  1.60588447e-01]])

# %% [markdown]
# 7. Create an array y with values [1100, 800, 750, 850, 1300, 1000, 1000, 1300, 800].

# %%
y = np.array([1100, 800, 750, 850, 1300, 1000, 1000, 1300, 800])

# %%
y
# Out:
# array([1100,  800,  750,  850, 1300, 1000, 1000, 1300,  800])

# %% [markdown]
# 8. Multiply the inverse of XTX with the transpose of X, and then multiply the result by y. Call the result w.

# %%
w = XTX_inv.dot(X.T).dot(y)

# %%
w
# Out:
# array([  4.59494481, -63.56432501])

# %% [markdown]
# 9. What's the value of the first element of w?

# %%
w[0]
# Out:
# 4.594944810094579
